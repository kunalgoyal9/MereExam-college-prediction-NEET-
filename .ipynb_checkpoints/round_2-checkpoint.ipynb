# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data2 = pd.read_csv('tabula-mccneet.csv', sep=',', header=None)

# %%
data2 = data2.set_index(0)

# %%
data2[9].unique()
# Out:
# array(['Did Not Opt for\rUpgradation', 'Not Reported Seat\rCancelled',
#        'Allotted seat from\rfresh choices', 'Allotted in 2nd Round',
#        'No Upgradation', 'Did not fill up fresh\rchoices', 'Resigned',
#        'Retained *', 'Admission of Previoud\rRound Cancelled'], dtype=object)

# %%
#data2.to_csv

# %%
data2.head()
# Out:
#     1                                         2     3    4    5    6    7   8  \
# 0
# 1   1  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN  NaN  NaN NaN
# 2   4         BANGALORE MED.\rCOLLEGE,BANGALORE  MBBS  NaN  NaN  NaN  NaN NaN
# 3   7  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN  NaN  NaN NaN
# 4   8  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN  NaN  NaN NaN
# 5  10  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN  NaN  NaN NaN
#
#                               9
# 0
# 1  Did Not Opt for\rUpgradation
# 2  Not Reported Seat\rCancelled
# 3  Did Not Opt for\rUpgradation
# 4  Did Not Opt for\rUpgradation
# 5  Not Reported Seat\rCancelled

# %%
mask = data2[9]=='Allotted seat from\rfresh choices'
data2.loc[mask,2]=data2.loc[mask,4]
data2.loc[mask,3] = data2.loc[mask,5] 
mask2 = data2[9]=='Allotted in 2nd Round'
data2.loc[mask2,2]=data2.loc[mask2,4]
data2.loc[mask2,3]=data2.loc[mask2,5]

# %%
data2[mask2].head()
# Out:
#        1                                                  2     3  \
# 0
# 30    48           MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS
# 137  185     University College of Medical\rSciences, Delhi  MBBS
# 153  205  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS
# 159  213  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS
# 166  220  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS
#
#                                                      4     5   6   7    8  \
# 0
# 30            MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  UR  UR  1.0
# 137     University College of Medical\rSciences, Delhi  MBBS  UR  UR  3.0
# 153  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS  UR  UR  4.0
# 159  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS  UR  UR  4.0
# 166  GOVERNMENT MEDICAL\rCOLLEGE AND HOSPITAL,\rCHA...  MBBS  UR  UR  1.0
#
#                          9
# 0
# 30   Allotted in 2nd Round
# 137  Allotted in 2nd Round
# 153  Allotted in 2nd Round
# 159  Allotted in 2nd Round
# 166  Allotted in 2nd Round

# %%
data2[mask].head()
# Out:
#       1                                               2     3  \
# 0
# 29   45        MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS
# 31   49        MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS
# 43   64        VMMC AND SAFDARJUNG\rHOSPITAL, NEW DELHI  MBBS
# 45   67        VMMC AND SAFDARJUNG\rHOSPITAL, NEW DELHI  MBBS
# 85  119  University College of Medical\rSciences, Delhi  MBBS
#
#                                                  4     5   6   7    8  \
# 0
# 29        MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  UR  UR  1.0
# 31        MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  UR  UR  1.0
# 43        VMMC AND SAFDARJUNG\rHOSPITAL, NEW DELHI  MBBS  UR  UR  2.0
# 45        VMMC AND SAFDARJUNG\rHOSPITAL, NEW DELHI  MBBS  UR  UR  2.0
# 85  University College of Medical\rSciences, Delhi  MBBS  UR  UR  2.0
#
#                                     9
# 0
# 29  Allotted seat from\rfresh choices
# 31  Allotted seat from\rfresh choices
# 43  Allotted seat from\rfresh choices
# 45  Allotted seat from\rfresh choices
# 85  Allotted seat from\rfresh choices

# %%
data2 = data2.drop([4,9],axis=1)

# %%
data2 = data2.drop([5,8],axis=1)

# %%
data2.tail()
# Out:
#            1                                                  2     3      6  \
# 0
# 6660  533334                    GOVT.MEDICAL COLLEGE,\rAMRITSAR  MBBS  SC PH
# 6661  541367                THENI GOVT. MEDICAL\rCOLLEGE, THENI  MBBS  SC PH
# 6662  547950  Andaman and Nicobar Islands\rInstitute of Medi...  MBBS  SC PH
# 6663  551407            CHENGALPATTU MEDICAL\rCOLL,CHENGALPATTU  MBBS    NaN
# 6664  551965      Karwar Institute of Medical\rSciences, Karwar  MBBS    NaN
#
#            7
# 0
# 6660  SC PH1
# 6661  SC PH2
# 6662  SC PH2
# 6663     NaN
# 6664     NaN

# %%
data1 = pd.read_csv('round_1_alloted.csv',header = None)
data1 = data1.set_index(0)
data1.head()
# Out:
#     1                                         2     3   4   5         6
# 0
# 1   1  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI  MBBS  UR  UR  Allotted
# 2   4          BANGALORE MED. COLLEGE,BANGALORE  MBBS  UR  UR  Allotted
# 3   7  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI  MBBS  UR  UR  Allotted
# 4   8  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI  MBBS  UR  UR  Allotted
# 5  10  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI  MBBS  UR  UR  Allotted

# %%
data2.head()
# Out:
#     1                                         2     3    6    7
# 0
# 1   1  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN
# 2   4         BANGALORE MED.\rCOLLEGE,BANGALORE  MBBS  NaN  NaN
# 3   7  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN
# 4   8  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN
# 5  10  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI  MBBS  NaN  NaN

# %%
data1 = data1.drop(6,axis=1)

# %%
data1.columns = ['Id', 'College','Course','6','7']

# %%
data1.head()
# Out:
#    Id                                   College Course   6   7
# 0
# 1   1  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI   MBBS  UR  UR
# 2   4          BANGALORE MED. COLLEGE,BANGALORE   MBBS  UR  UR
# 3   7  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI   MBBS  UR  UR
# 4   8  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI   MBBS  UR  UR
# 5  10  MAULANA AZAD MEDICAL COLLEGE, NEW\rDELHI   MBBS  UR  UR

# %%
data2.columns = data1.columns

# %%
import re
def correct(data):
    data = re.sub(r'\n', ' ', str(data))
    return re.sub(r'\r', ' ', str(data))

# %%
correct('jkshkfhsf\n jflksj\r sjlsj')
# Out:
# 'jkshkfhsf  jflksj  sjlsj'

# %%
out_data = data2.merge(data1, on='Id',how='outer')
out_data['College_x'] = out_data['College_x'].apply(correct)
out_data['College_y'] = out_data['College_y'].apply(correct)
#out_data.to_csv('out_data.csv')
out_data['College_y']
# Out:
# 0                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 1                        BANGALORE MED. COLLEGE,BANGALORE
# 2                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 3                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 4                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 5                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 6                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 7                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 8                 MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 9                         GOVT. MEDICAL COLLEGE, KOTTAYAM
# 10                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 11                      GOVERNMENT MEDICAL COLLEGE, SURAT
# 12                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 13                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 14                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 15                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 16                      SETH G.S. MEDICAL COLLEGE, MUMBAI
# 17                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 18                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 19                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 20                       BANGALORE MED. COLLEGE,BANGALORE
# 21                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 22                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 23                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 24                MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 25                GOVT.MEDICAL COLLEGE,THIRUVANANTHAPURAM
# 26                GOVT.MEDICAL COLLEGE,THIRUVANANTHAPURAM
# 27                                  IMS BHU, Varanasi, UP
# 28               LADY HARDINGE MEDICAL COLLEGE, NEW DELHI
# 29                                                    nan
#                               ...
# 6613                                                  nan
# 6614                                                  nan
# 6615                                                  nan
# 6616                                                  nan
# 6617              Darbhanga Medical College, Laheriasarai
# 6618                     Govt. Sivgangai M. C. Sivagangai
# 6619                                                  nan
# 6620                                                  nan
# 6621              VMMC AND SAFDARJUNG HOSPITAL, NEW DELHI
# 6622    Sh. Lal Bahadur Shastri Govt. Med. College. Mandi
# 6623                      BPS Govt. Med. College, Sonepat
# 6624                                                  nan
# 6625                                                  nan
# 6626               CHENGALPATTU MEDICAL COLL,CHENGALPATTU
# 6627         Karwar Institute of Medical Sciences, Karwar
# 6628             BAHIRAMJEE JIJIBHAI MEDICAL COLLGE, PUNE
# 6629            Government Doon Medcial College, Dehradun
# 6630                  M.P. SHAH MEDICAL COLLEGE, JAMNAGAR
# 6631               BELGAUM INST. OF MEDICAL SCI., BELGAUM
# 6632     Pt. Jawahar Lal Nehru Govt. Med. College, Chamba
# 6633    Sheikh-Ul-Hind Maulana Mahmood Hasan Medical C...
# 6634      Govt. Medical College and  Hospital, Chandrapur
# 6635                      MADRAS MEDICAL COLLEGE, CHENNAI
# 6636          Jorhat Medical College and Hospital, JORHAT
# 6637                         IMS BHU Dental, Varanasi, UP
# 6638                      S.C.B. MEDICAL COLLEGE, CUTTACK
# 6639                        G.R. MEDICAL COLLEGE, GWALIOR
# 6640    Saheed Laxman Nayak Med. College and Hos., Kor...
# 6641              THOOTHUKUDI MEDICAL COLLEGE,THOOTHUKUDI
# 6642                                     GTMC, THIRUVARUR
# Name: College_y, Length: 6643, dtype: object

# %%
out_data.head()
# Out:
#    Id                                College_x Course_x  6_x  7_x  \
# 0   1  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  NaN  NaN
# 1   4         BANGALORE MED. COLLEGE,BANGALORE     MBBS  NaN  NaN
# 2   7  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  NaN  NaN
# 3   8  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  NaN  NaN
# 4  10  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  NaN  NaN
#
#                                  College_y Course_y 6_y 7_y
# 0  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  UR  UR
# 1         BANGALORE MED. COLLEGE,BANGALORE     MBBS  UR  UR
# 2  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  UR  UR
# 3  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  UR  UR
# 4  MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS  UR  UR

# %%
mask = (out_data['6_y'].isnull())
out_data.loc[mask,'6_y']=out_data.loc[mask,'6_x']
out_data.loc[mask,'7_y']=out_data.loc[mask,'7_x']

# %%
mask_col1 = out_data['College_x'].isnull()
out_data.loc[mask_col1, 'College_x'] = out_data.loc[mask_col1,'College_y']
#out_data[mask_col1]

# %%
mask_col2 = out_data['College_y'].isnull()
out_data.loc[mask_col2, 'College_y'] = out_data.loc[mask_col2,'College_x']

# %%
out_data[mask_col2]
# Out:
# Empty DataFrame
# Columns: [Id, College_x, Course_x, 6_x, 7_x, College_y, Course_y, 6_y, 7_y]
# Index: []

# %%
mask = (out_data['6_x'].isnull())
out_data.loc[mask,'6_x']=out_data.loc[mask,'6_y']
out_data.loc[mask,'7_x']=out_data.loc[mask,'7_y']
out_data[mask]
# Out:
#           Id                                          College_x Course_x  \
# 0          1            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 1          4                   BANGALORE MED. COLLEGE,BANGALORE     MBBS
# 2          7            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 3          8            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 4         10            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 5         12            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 6         15            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 7         17            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 8         18            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 9         19                    GOVT. MEDICAL COLLEGE, KOTTAYAM     MBBS
# 10        20            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 11        21                  GOVERNMENT MEDICAL COLLEGE, SURAT     MBBS
# 12        22            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 13        23            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 14        24            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 15        25            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 16        26                  SETH G.S. MEDICAL COLLEGE, MUMBAI     MBBS
# 17        30            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 18        31            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 19        32            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 20        34                   BANGALORE MED. COLLEGE,BANGALORE     MBBS
# 21        35            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 22        36            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 23        37            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 24        38            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI     MBBS
# 25        39           GOVT.MEDICAL COLLEGE,THIRUVANANTHAPUR AM     MBBS
# 26        41           GOVT.MEDICAL COLLEGE,THIRUVANANTHAPUR AM     MBBS
# 27        43                              IMS BHU, Varanasi, UP     MBBS
# 31        50                   GOVT. MEDICAL COLLEGE, KOZHIKODE     MBBS
# 32        51            VMMC AND SAFDARJUNG HOSPITAL, NEW DELHI     MBBS
# ...      ...                                                ...      ...
# 6560  405115                    B.J. MEDICAL COLLEGE, AHMEDABAD     MBBS
# 6568  419447              MAHARAJA K.C. GAJAPATI M.C.,BRAHMAPUR     MBBS
# 6570  425195              MAHARAJA K.C. GAJAPATI M.C.,BRAHMAPUR     MBBS
# 6578  448469                  GOVT. MEDICAL COLLEGE,TIRUNELVELI     MBBS
# 6585  467453       Karwar Institute of Medical Sciences, Karwar     MBBS
# 6587  471758            DR. VAISHAMPAYAM MEMORIAL M.C.,SHOLAPUR     MBBS
# 6588  472397                     GOVT.MEDICAL COLLEGE, AMRITSAR     MBBS
# 6589  473399                    MADRAS MEDICAL COLLEGE, CHENNAI     MBBS
# 6594  482699            DR. VAISHAMPAYAM MEMORIAL M.C.,SHOLAPUR     MBBS
# 6597  486476                    BURDWAN MEDICAL COLLEGE,BURDWAN     MBBS
# 6602  496623   C. Institute of Medical Sciences, Chamarajanagar     MBBS
# 6621  531946            VMMC AND SAFDARJUNG HOSPITAL, NEW DELHI     MBBS
# 6622  533284  Sh. Lal Bahadur Shastri Govt. Med. College. Mandi     MBBS
# 6626  551407             CHENGALPATTU MEDICAL COLL,CHENGALPATTU     MBBS
# 6627  551965       Karwar Institute of Medical Sciences, Karwar     MBBS
# 6628     883                                                nan      NaN
# 6629    2408                                                nan      NaN
# 6630    2479                                                nan      NaN
# 6631    3840                                                nan      NaN
# 6632    3881                                                nan      NaN
# 6633    3901                                                nan      NaN
# 6634    5275                                                nan      NaN
# 6635    5643                                                nan      NaN
# 6636    5745                                                nan      NaN
# 6637    6502                                                nan      NaN
# 6638   12872                                                nan      NaN
# 6639   14862                                                nan      NaN
# 6640   28575                                                nan      NaN
# 6641   59457                                                nan      NaN
# 6642   60543                                                nan      NaN
#
#         6_x     7_x                                          College_y  \
# 0        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 1        UR      UR                   BANGALORE MED. COLLEGE,BANGALORE
# 2        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 3        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 4        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 5        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 6        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 7        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 8        UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 9        UR      UR                    GOVT. MEDICAL COLLEGE, KOTTAYAM
# 10       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 11       UR      UR                  GOVERNMENT MEDICAL COLLEGE, SURAT
# 12       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 13       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 14       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 15       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 16       UR      UR                  SETH G.S. MEDICAL COLLEGE, MUMBAI
# 17       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 18       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 19       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 20       UR      UR                   BANGALORE MED. COLLEGE,BANGALORE
# 21       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 22       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 23       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 24       UR      UR            MAULANA AZAD MEDICAL COLLEGE, NEW DELHI
# 25       UR      UR            GOVT.MEDICAL COLLEGE,THIRUVANANTHAPURAM
# 26       UR      UR            GOVT.MEDICAL COLLEGE,THIRUVANANTHAPURAM
# 27       UR      UR                              IMS BHU, Varanasi, UP
# 31       UR     OBC                   GOVT. MEDICAL COLLEGE, KOZHIKODE
# 32       UR      UR            VMMC AND SAFDARJUNG HOSPITAL, NEW DELHI
# ...     ...     ...                                                ...
# 6560  SC PH  SC PH1                    B.J. MEDICAL COLLEGE, AHMEDABAD
# 6568  SC PH  SC PH1              MAHARAJA K.C. GAJAPATI M.C.,BRAHMAPUR
# 6570  ST PH  ST PH2              MAHARAJA K.C. GAJAPATI M.C.,BRAHMAPUR
# 6578  ST PH  ST PH2                  GOVT. MEDICAL COLLEGE,TIRUNELVELI
# 6585  ST PH  ST PH2       Karwar Institute of Medical Sciences, Karwar
# 6587  SC PH  SC PH1            DR. VAISHAMPAYAM MEMORIAL M.C.,SHOLAPUR
# 6588  SC PH  SC PH1                     GOVT.MEDICAL COLLEGE, AMRITSAR
# 6589  SC PH  SC PH1                    MADRAS MEDICAL COLLEGE, CHENNAI
# 6594  ST PH  ST PH2            DR. VAISHAMPAYAM MEMORIAL M.C.,SHOLAPUR
# 6597  SC PH  SC PH1                    BURDWAN MEDICAL COLLEGE,BURDWAN
# 6602  SC PH  SC PH1   C. Institute of Medical Sciences, Chamarajanagar
# 6621  ST PH  ST PH1            VMMC AND SAFDARJUNG HOSPITAL, NEW DELHI
# 6622  ST PH  ST PH1  Sh. Lal Bahadur Shastri Govt. Med. College. Mandi
# 6626  SC PH  SC PH1             CHENGALPATTU MEDICAL COLL,CHENGALPATTU
# 6627  SC PH  SC PH1       Karwar Institute of Medical Sciences, Karwar
# 6628     UR      UR           BAHIRAMJEE JIJIBHAI MEDICAL COLLGE, PUNE
# 6629     UR      UR          Government Doon Medcial College, Dehradun
# 6630     UR     OBC                M.P. SHAH MEDICAL COLLEGE, JAMNAGAR
# 6631     UR     OBC             BELGAUM INST. OF MEDICAL SCI., BELGAUM
# 6632     UR      UR   Pt. Jawahar Lal Nehru Govt. Med. College, Chamba
# 6633     UR      UR  Sheikh-Ul-Hind Maulana Mahmood Hasan Medical C...
# 6634     UR      UR    Govt. Medical College and  Hospital, Chandrapur
# 6635     SC      SC                    MADRAS MEDICAL COLLEGE, CHENNAI
# 6636     UR     OBC        Jorhat Medical College and Hospital, JORHAT
# 6637     UR     OBC                       IMS BHU Dental, Varanasi, UP
# 6638     SC      SC                    S.C.B. MEDICAL COLLEGE, CUTTACK
# 6639     SC      SC                      G.R. MEDICAL COLLEGE, GWALIOR
# 6640     SC      SC  Saheed Laxman Nayak Med. College and Hos., Kor...
# 6641     ST      ST            THOOTHUKUDI MEDICAL COLLEGE,THOOTHUKUDI
# 6642     ST      ST                                   GTMC, THIRUVARUR
#
#      Course_y    6_y     7_y
# 0        MBBS     UR      UR
# 1        MBBS     UR      UR
# 2        MBBS     UR      UR
# 3        MBBS     UR      UR
# 4        MBBS     UR      UR
# 5        MBBS     UR      UR
# 6        MBBS     UR      UR
# 7        MBBS     UR      UR
# 8        MBBS     UR      UR
# 9        MBBS     UR      UR
# 10       MBBS     UR      UR
# 11       MBBS     UR      UR
# 12       MBBS     UR      UR
# 13       MBBS     UR      UR
# 14       MBBS     UR      UR
# 15       MBBS     UR      UR
# 16       MBBS     UR      UR
# 17       MBBS     UR      UR
# 18       MBBS     UR      UR
# 19       MBBS     UR      UR
# 20       MBBS     UR      UR
# 21       MBBS     UR      UR
# 22       MBBS     UR      UR
# 23       MBBS     UR      UR
# 24       MBBS     UR      UR
# 25       MBBS     UR      UR
# 26       MBBS     UR      UR
# 27       MBBS     UR      UR
# 31       MBBS     UR     OBC
# 32       MBBS     UR      UR
# ...       ...    ...     ...
# 6560     MBBS  SC PH  SC PH1
# 6568     MBBS  SC PH  SC PH1
# 6570     MBBS  ST PH  ST PH2
# 6578     MBBS  ST PH  ST PH2
# 6585     MBBS  ST PH  ST PH2
# 6587     MBBS  SC PH  SC PH1
# 6588     MBBS  SC PH  SC PH1
# 6589     MBBS  SC PH  SC PH1
# 6594     MBBS  ST PH  ST PH2
# 6597     MBBS  SC PH  SC PH1
# 6602     MBBS  SC PH  SC PH1
# 6621     MBBS  ST PH  ST PH1
# 6622     MBBS  ST PH  ST PH1
# 6626     MBBS  SC PH  SC PH1
# 6627     MBBS  SC PH  SC PH1
# 6628     MBBS     UR      UR
# 6629     MBBS     UR      UR
# 6630     MBBS     UR     OBC
# 6631     MBBS     UR     OBC
# 6632     MBBS     UR      UR
# 6633     MBBS     UR      UR
# 6634     MBBS     UR      UR
# 6635     MBBS     SC      SC
# 6636     MBBS     UR     OBC
# 6637      BDS     UR     OBC
# 6638     MBBS     SC      SC
# 6639     MBBS     SC      SC
# 6640     MBBS     SC      SC
# 6641     MBBS     ST      ST
# 6642     MBBS     ST      ST
#
# [3273 rows x 9 columns]

# %%
out_data=out_data.drop(['College_y','Course_y','6_y','7_y'],axis=1)
out_data.head()
# Out:
#    Id                                 College_x Course_x 6_x 7_x
# 0   1  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI     MBBS  UR  UR
# 1   4         BANGALORE MED.\rCOLLEGE,BANGALORE     MBBS  UR  UR
# 2   7  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI     MBBS  UR  UR
# 3   8  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI     MBBS  UR  UR
# 4  10  MAULANA AZAD MEDICAL\rCOLLEGE, NEW DELHI     MBBS  UR  UR

# %%
out_data.to_csv('refined_round_2.csv',header=None)

# %%
out_data.shape
# Out:
# (6643, 5)
